# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	#re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			#line = normalize('NFD', line).encode('ascii', 'ignore')
			#line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			#line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			#line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
		#	line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'nob.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-Norwegian.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-Norwegian.pkl
# [Who] => [Hvem]
# [Wow] => [Oi]
# [Fire] => [Brann]
# [Fire] => [Skyt]
# [Help] => [Hjelp]
# [Stop] => [Slutt]
# [Stop] => [Stopp]
# [Shoot] => [Skyt]
# [Attack] => [Angrip]
# [Got it] => [Jeg skjønner]
# [I know] => [Jeg vet]
# [Really] => [Virkelig]
# [Thanks] => [Takk skal du ha]
# [Come on] => [Kom igjen]
# [Get out] => [Forsvinn]
# [Get out] => [Kom deg ut]
# [Go away] => [Gå vekk]
# [Goodbye] => [Ha det]
# [Help me] => [Hjelp meg]
# [Help me] => [Hjelp meg]
# [I agree] => [Jeg er enig]
# [Kiss me] => [Kyss meg]
# [See you] => [Vi sees]
# [Show me] => [Vis meg]
# [Shut up] => [Hold kjeft]
# [Wake up] => [Våkn opp]
# [Welcome] => [Velkommen]
# [Good job] => [Bra jobbet]
# [Good job] => [Godt gjort]
# [Hurry up] => [Skynd deg]
# [Im bald] => [Jeg er skallet]
# [Im bald] => [Jeg er skalla]
# [Im deaf] => [Jeg er døv]
# [Im fine] => [Det går bra med meg]
# [Im home] => [Jeg er hjemme]
# [Stand up] => [Reis dere]
# [Tom knew] => [Tom visste]
# [We agree] => [Vi er enige]
# [Who came] => [Hvem kom]
# [Whos he] => [Hvem er han]
# [Come back] => [Kom tilbake]
# [Come soon] => [Kom snart]
# [Follow us] => [Følg oss]
# [Forget it] => [Glem det]
# [Get a job] => [Finn deg en jobb]
# [Goodnight] => [God natt]
# [Hands off] => [Ikke rør]
# [Hold this] => [Hold dette]
# [Id agree] => [Jeg er enig]
# [Im a vet] => [Jeg er veteran]
# [Im naked] => [Jeg er naken]
# [Im tired] => [Jeg er trøtt]
# [Its mine] => [Den er min]
# [Its mine] => [Det er mitt]
# [Its true] => [Det er sant]
# [Its warm] => [Det er varmt]
# [Open fire] => [Skyt]
# [Pardon me] => [Unnskyld meg]
# [Seriously] => [Seriøst]
# [She cried] => [Hun gråt]
# [She walks] => [Hun går]
# [Thank you] => [Takk skal du ha]
# [They swam] => [De har svømt]
# [Tom stood] => [Tom stod]
# [Try again] => [Prøv på nytt]
# [Try again] => [Prøv igjen]
# [Whats up] => [Hva skjer]
# [Who is he] => [Hvem er han]
# [Who knows] => [Hvem vet]
# [Are you in] => [Er du med]
# [Good night] => [God natt]
# [He is kind] => [Han er snill]
# [How clever] => [Så lurt]
# [I am happy] => [Jeg er lykkelig]
# [I just ate] => [Jeg spiste nettopp]
# [I love you] => [Jeg elsker deg]
# [I miss you] => [Jeg savner deg]
# [I was home] => [Jeg var hjemme]
# [Ill do it] => [Jeg skal gjøre det]
# [Im a hero] => [Jeg er en helt]
# [Im chubby] => [Jeg er lubben]
# [Im coming] => [Jeg kommer]
# [Im so fat] => [Jeg er så tykk]
# [Im so fat] => [Jeg er så tjukk]
# [Im so fat] => [Jeg er så feit]
# [Is he tall] => [Er han høy]
# [Is it blue] => [Er det blått]
# [It happens] => [Sånt skjer]
# [It is warm] => [Det er varmt]
# [Now try it] => [Prøv det nå]
# [Tom called] => [Tom ringte]
# [You may go] => [Du kan gå]
# [Are you sad] => [Du er vel ikke trist]
# [Dont panic] => [Ikke få panikk]
# [Dont shoot] => [Ikke skyt]
# [Dont shoot] => [Ikke skyt]
# [How are you] => [Hvordan går det]
# [I eat bread] => [Jeg spiser brød]
# [I hate dogs] => [Jeg hater hunder]
# [I hate math] => [Jeg hater matematikk]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-Norwegian.pkl')

# reduce dataset size
n_sentences = 6015
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:5000], dataset[1015:]
# save
save_clean_data(dataset, 'english-Norwegian-both.pkl')
save_clean_data(train, 'english-Norwegian-train.pkl')
save_clean_data(test, 'english-Norwegian-test.pkl')
# Out:
# Saved: english-Norwegian-both.pkl
# Saved: english-Norwegian-train.pkl
# Saved: english-Norwegian-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-Norwegian-both.pkl')
train = load_clean_sentences('english-Norwegian-train.pkl')
test = load_clean_sentences('english-Norwegian-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Norwegian Vocabulary Size: %d' % ger_vocab_size)
print('Norwegian  Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 3499
# English Max Length: 27
# Norwegian Vocabulary Size: 4272
# Norwegian  Max Length: 22
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 22, 256)           1093632
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 27, 256)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 27, 256)           525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 27, 3499)          899243
# =================================================================
# Total params: 3,043,499
# Trainable params: 3,043,499
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 79/79 - 75s - loss: 2.6682 - val_loss: 1.6385
#
# Epoch 00001: val_loss improved from inf to 1.63851, saving model to model.h5
# Epoch 2/100
# 79/79 - 68s - loss: 1.5982 - val_loss: 1.5769
#
# Epoch 00002: val_loss improved from 1.63851 to 1.57689, saving model to model.h5
# Epoch 3/100
# 79/79 - 69s - loss: 1.5554 - val_loss: 1.5233
#
# Epoch 00003: val_loss improved from 1.57689 to 1.52332, saving model to model.h5
# Epoch 4/100
# 79/79 - 68s - loss: 1.5174 - val_loss: 1.5147
#
# Epoch 00004: val_loss improved from 1.52332 to 1.51466, saving model to model.h5
# Epoch 5/100
# 79/79 - 68s - loss: 1.4475 - val_loss: 1.4215
#
# Epoch 00005: val_loss improved from 1.51466 to 1.42147, saving model to model.h5
# Epoch 6/100
# 79/79 - 68s - loss: 1.4029 - val_loss: 1.3958
#
# Epoch 00006: val_loss improved from 1.42147 to 1.39578, saving model to model.h5
# Epoch 7/100
# 79/79 - 68s - loss: 1.3845 - val_loss: 1.3899
#
# Epoch 00007: val_loss improved from 1.39578 to 1.38991, saving model to model.h5
# Epoch 8/100
# 79/79 - 68s - loss: 1.3716 - val_loss: 1.3764
#
# Epoch 00008: val_loss improved from 1.38991 to 1.37638, saving model to model.h5
# Epoch 9/100
# 79/79 - 68s - loss: 1.3610 - val_loss: 1.3622
#
# Epoch 00009: val_loss improved from 1.37638 to 1.36224, saving model to model.h5
# Epoch 10/100
# 79/79 - 68s - loss: 1.3531 - val_loss: 1.3603
#
# Epoch 00010: val_loss improved from 1.36224 to 1.36032, saving model to model.h5
# Epoch 11/100
# 79/79 - 68s - loss: 1.3440 - val_loss: 1.3463
#
# Epoch 00011: val_loss improved from 1.36032 to 1.34633, saving model to model.h5
# Epoch 12/100
# 79/79 - 69s - loss: 1.3307 - val_loss: 1.3405
#
# Epoch 00012: val_loss improved from 1.34633 to 1.34049, saving model to model.h5
# Epoch 13/100
# 79/79 - 68s - loss: 1.3222 - val_loss: 1.3389
#
# Epoch 00013: val_loss improved from 1.34049 to 1.33895, saving model to model.h5
# Epoch 14/100
# 79/79 - 67s - loss: 1.3194 - val_loss: 1.3365
#
# Epoch 00014: val_loss improved from 1.33895 to 1.33648, saving model to model.h5
# Epoch 15/100
# 79/79 - 67s - loss: 1.3121 - val_loss: 1.3317
#
# Epoch 00015: val_loss improved from 1.33648 to 1.33170, saving model to model.h5
# Epoch 16/100
# 79/79 - 67s - loss: 1.3025 - val_loss: 1.3217
#
# Epoch 00016: val_loss improved from 1.33170 to 1.32173, saving model to model.h5
# Epoch 17/100
# 79/79 - 68s - loss: 1.2960 - val_loss: 1.3197
#
# Epoch 00017: val_loss improved from 1.32173 to 1.31973, saving model to model.h5
# Epoch 18/100
# 79/79 - 67s - loss: 1.2901 - val_loss: 1.3109
#
# Epoch 00018: val_loss improved from 1.31973 to 1.31091, saving model to model.h5
# Epoch 19/100
# 79/79 - 67s - loss: 1.2813 - val_loss: 1.3049
#
# Epoch 00019: val_loss improved from 1.31091 to 1.30491, saving model to model.h5
# Epoch 20/100
# 79/79 - 67s - loss: 1.2765 - val_loss: 1.3028
#
# Epoch 00020: val_loss improved from 1.30491 to 1.30281, saving model to model.h5
# Epoch 21/100
# 79/79 - 67s - loss: 1.2685 - val_loss: 1.2978
#
# Epoch 00021: val_loss improved from 1.30281 to 1.29781, saving model to model.h5
# Epoch 22/100
# 79/79 - 68s - loss: 1.2611 - val_loss: 1.2992
#
# Epoch 00022: val_loss did not improve from 1.29781
# Epoch 23/100
# 79/79 - 67s - loss: 1.2534 - val_loss: 1.2917
#
# Epoch 00023: val_loss improved from 1.29781 to 1.29174, saving model to model.h5
# Epoch 24/100
# 79/79 - 67s - loss: 1.2422 - val_loss: 1.2721
#
# Epoch 00024: val_loss improved from 1.29174 to 1.27206, saving model to model.h5
# Epoch 25/100
# 79/79 - 67s - loss: 1.2311 - val_loss: 1.2680
#
# Epoch 00025: val_loss improved from 1.27206 to 1.26802, saving model to model.h5
# Epoch 26/100
# 79/79 - 69s - loss: 1.2181 - val_loss: 1.2624
#
# Epoch 00026: val_loss improved from 1.26802 to 1.26243, saving model to model.h5
# Epoch 27/100
# 79/79 - 68s - loss: 1.2052 - val_loss: 1.2363
#
# Epoch 00027: val_loss improved from 1.26243 to 1.23626, saving model to model.h5
# Epoch 28/100
# 79/79 - 67s - loss: 1.1876 - val_loss: 1.2220
#
# Epoch 00028: val_loss improved from 1.23626 to 1.22196, saving model to model.h5
# Epoch 29/100
# 79/79 - 67s - loss: 1.1708 - val_loss: 1.2105
#
# Epoch 00029: val_loss improved from 1.22196 to 1.21047, saving model to model.h5
# Epoch 30/100
# 79/79 - 67s - loss: 1.1574 - val_loss: 1.2058
#
# Epoch 00030: val_loss improved from 1.21047 to 1.20575, saving model to model.h5
# Epoch 31/100
# 79/79 - 68s - loss: 1.1413 - val_loss: 1.1890
#
# Epoch 00031: val_loss improved from 1.20575 to 1.18901, saving model to model.h5
# Epoch 32/100
# 79/79 - 67s - loss: 1.1279 - val_loss: 1.1872
#
# Epoch 00032: val_loss improved from 1.18901 to 1.18719, saving model to model.h5
# Epoch 33/100
# 79/79 - 67s - loss: 1.1095 - val_loss: 1.1513
#
# Epoch 00033: val_loss improved from 1.18719 to 1.15134, saving model to model.h5
# Epoch 34/100
# 79/79 - 68s - loss: 1.0872 - val_loss: 1.1373
#
# Epoch 00034: val_loss improved from 1.15134 to 1.13733, saving model to model.h5
# Epoch 35/100
# 79/79 - 67s - loss: 1.0708 - val_loss: 1.1338
#
# Epoch 00035: val_loss improved from 1.13733 to 1.13382, saving model to model.h5
# Epoch 36/100
# 79/79 - 68s - loss: 1.0523 - val_loss: 1.1044
#
# Epoch 00036: val_loss improved from 1.13382 to 1.10438, saving model to model.h5
# Epoch 37/100
# 79/79 - 67s - loss: 1.0362 - val_loss: 1.0889
#
# Epoch 00037: val_loss improved from 1.10438 to 1.08888, saving model to model.h5
# Epoch 38/100
# 79/79 - 68s - loss: 1.0133 - val_loss: 1.1073
#
# Epoch 00038: val_loss did not improve from 1.08888
# Epoch 39/100
# 79/79 - 67s - loss: 1.0010 - val_loss: 1.0565
#
# Epoch 00039: val_loss improved from 1.08888 to 1.05652, saving model to model.h5
# Epoch 40/100
# 79/79 - 68s - loss: 0.9745 - val_loss: 1.0331
#
# Epoch 00040: val_loss improved from 1.05652 to 1.03308, saving model to model.h5
# Epoch 41/100
# 79/79 - 68s - loss: 0.9524 - val_loss: 1.0168
#
# Epoch 00041: val_loss improved from 1.03308 to 1.01680, saving model to model.h5
# Epoch 42/100
# 79/79 - 67s - loss: 0.9305 - val_loss: 1.0014
#
# Epoch 00042: val_loss improved from 1.01680 to 1.00139, saving model to model.h5
# Epoch 43/100
# 79/79 - 67s - loss: 0.9139 - val_loss: 0.9950
#
# Epoch 00043: val_loss improved from 1.00139 to 0.99496, saving model to model.h5
# Epoch 44/100
# 79/79 - 67s - loss: 0.8984 - val_loss: 0.9707
#
# Epoch 00044: val_loss improved from 0.99496 to 0.97068, saving model to model.h5
# Epoch 45/100
# 79/79 - 68s - loss: 0.8797 - val_loss: 0.9522
#
# Epoch 00045: val_loss improved from 0.97068 to 0.95218, saving model to model.h5
# Epoch 46/100
# 79/79 - 67s - loss: 0.8555 - val_loss: 0.9317
#
# Epoch 00046: val_loss improved from 0.95218 to 0.93171, saving model to model.h5
# Epoch 47/100
# 79/79 - 67s - loss: 0.8348 - val_loss: 0.9183
#
# Epoch 00047: val_loss improved from 0.93171 to 0.91828, saving model to model.h5
# Epoch 48/100
# 79/79 - 67s - loss: 0.8162 - val_loss: 0.9046
#
# Epoch 00048: val_loss improved from 0.91828 to 0.90457, saving model to model.h5
# Epoch 49/100
# 79/79 - 68s - loss: 0.7959 - val_loss: 0.8856
#
# Epoch 00049: val_loss improved from 0.90457 to 0.88560, saving model to model.h5
# Epoch 50/100
# 79/79 - 68s - loss: 0.7739 - val_loss: 0.8735
#
# Epoch 00050: val_loss improved from 0.88560 to 0.87350, saving model to model.h5
# Epoch 51/100
# 79/79 - 67s - loss: 0.7577 - val_loss: 0.8587
#
# Epoch 00051: val_loss improved from 0.87350 to 0.85872, saving model to model.h5
# Epoch 52/100
# 79/79 - 67s - loss: 0.7383 - val_loss: 0.8373
#
# Epoch 00052: val_loss improved from 0.85872 to 0.83735, saving model to model.h5
# Epoch 53/100
# 79/79 - 67s - loss: 0.7209 - val_loss: 0.8247
#
# Epoch 00053: val_loss improved from 0.83735 to 0.82470, saving model to model.h5
# Epoch 54/100
# 79/79 - 68s - loss: 0.7035 - val_loss: 0.8098
#
# Epoch 00054: val_loss improved from 0.82470 to 0.80979, saving model to model.h5
# Epoch 55/100
# 79/79 - 68s - loss: 0.6833 - val_loss: 0.8027
#
# Epoch 00055: val_loss improved from 0.80979 to 0.80270, saving model to model.h5
# Epoch 56/100
# 79/79 - 68s - loss: 0.6676 - val_loss: 0.7807
#
# Epoch 00056: val_loss improved from 0.80270 to 0.78066, saving model to model.h5
# Epoch 57/100
# 79/79 - 68s - loss: 0.6468 - val_loss: 0.7679
#
# Epoch 00057: val_loss improved from 0.78066 to 0.76792, saving model to model.h5
# Epoch 58/100
# 79/79 - 68s - loss: 0.6285 - val_loss: 0.7538
#
# Epoch 00058: val_loss improved from 0.76792 to 0.75380, saving model to model.h5
# Epoch 59/100
# 79/79 - 68s - loss: 0.6128 - val_loss: 0.7471
#
# Epoch 00059: val_loss improved from 0.75380 to 0.74713, saving model to model.h5
# Epoch 60/100
# 79/79 - 68s - loss: 0.5980 - val_loss: 0.7255
#
# Epoch 00060: val_loss improved from 0.74713 to 0.72553, saving model to model.h5
# Epoch 61/100
# 79/79 - 68s - loss: 0.5809 - val_loss: 0.7164
#
# Epoch 00061: val_loss improved from 0.72553 to 0.71640, saving model to model.h5
# Epoch 62/100
# 79/79 - 67s - loss: 0.5653 - val_loss: 0.7015
#
# Epoch 00062: val_loss improved from 0.71640 to 0.70147, saving model to model.h5
# Epoch 63/100
# 79/79 - 68s - loss: 0.5462 - val_loss: 0.6886
#
# Epoch 00063: val_loss improved from 0.70147 to 0.68864, saving model to model.h5
# Epoch 64/100
# 79/79 - 69s - loss: 0.5281 - val_loss: 0.6794
#
# Epoch 00064: val_loss improved from 0.68864 to 0.67942, saving model to model.h5
# Epoch 65/100
# 79/79 - 68s - loss: 0.5156 - val_loss: 0.6658
#
# Epoch 00065: val_loss improved from 0.67942 to 0.66576, saving model to model.h5
# Epoch 66/100
# 79/79 - 67s - loss: 0.4990 - val_loss: 0.6547
#
# Epoch 00066: val_loss improved from 0.66576 to 0.65466, saving model to model.h5
# Epoch 67/100
# 79/79 - 68s - loss: 0.4869 - val_loss: 0.6491
#
# Epoch 00067: val_loss improved from 0.65466 to 0.64906, saving model to model.h5
# Epoch 68/100
# 79/79 - 68s - loss: 0.4712 - val_loss: 0.6364
#
# Epoch 00068: val_loss improved from 0.64906 to 0.63641, saving model to model.h5
# Epoch 69/100
# 79/79 - 68s - loss: 0.4557 - val_loss: 0.6266
#
# Epoch 00069: val_loss improved from 0.63641 to 0.62662, saving model to model.h5
# Epoch 70/100
# 79/79 - 68s - loss: 0.4466 - val_loss: 0.6149
#
# Epoch 00070: val_loss improved from 0.62662 to 0.61490, saving model to model.h5
# Epoch 71/100
# 79/79 - 68s - loss: 0.4277 - val_loss: 0.6039
#
# Epoch 00071: val_loss improved from 0.61490 to 0.60392, saving model to model.h5
# Epoch 72/100
# 79/79 - 68s - loss: 0.4127 - val_loss: 0.5931
#
# Epoch 00072: val_loss improved from 0.60392 to 0.59309, saving model to model.h5
# Epoch 73/100
# 79/79 - 68s - loss: 0.4027 - val_loss: 0.5822
#
# Epoch 00073: val_loss improved from 0.59309 to 0.58216, saving model to model.h5
# Epoch 74/100
# 79/79 - 68s - loss: 0.3889 - val_loss: 0.5852
#
# Epoch 00074: val_loss did not improve from 0.58216
# Epoch 75/100
# 79/79 - 68s - loss: 0.3820 - val_loss: 0.5709
#
# Epoch 00075: val_loss improved from 0.58216 to 0.57089, saving model to model.h5
# Epoch 76/100
# 79/79 - 68s - loss: 0.3709 - val_loss: 0.5614
#
# Epoch 00076: val_loss improved from 0.57089 to 0.56137, saving model to model.h5
# Epoch 77/100
# 79/79 - 67s - loss: 0.3560 - val_loss: 0.5528
#
# Epoch 00077: val_loss improved from 0.56137 to 0.55275, saving model to model.h5
# Epoch 78/100
# 79/79 - 68s - loss: 0.3431 - val_loss: 0.5434
#
# Epoch 00078: val_loss improved from 0.55275 to 0.54342, saving model to model.h5
# Epoch 79/100
# 79/79 - 67s - loss: 0.3319 - val_loss: 0.5336
#
# Epoch 00079: val_loss improved from 0.54342 to 0.53357, saving model to model.h5
# Epoch 80/100
# 79/79 - 67s - loss: 0.3195 - val_loss: 0.5239
#
# Epoch 00080: val_loss improved from 0.53357 to 0.52392, saving model to model.h5
# Epoch 81/100
# 79/79 - 68s - loss: 0.3111 - val_loss: 0.5150
#
# Epoch 00081: val_loss improved from 0.52392 to 0.51499, saving model to model.h5
# Epoch 82/100
# 79/79 - 67s - loss: 0.3012 - val_loss: 0.5100
#
# Epoch 00082: val_loss improved from 0.51499 to 0.51001, saving model to model.h5
# Epoch 83/100
# 79/79 - 68s - loss: 0.2936 - val_loss: 0.5047
#
# Epoch 00083: val_loss improved from 0.51001 to 0.50473, saving model to model.h5
# Epoch 84/100
# 79/79 - 67s - loss: 0.2805 - val_loss: 0.4950
#
# Epoch 00084: val_loss improved from 0.50473 to 0.49502, saving model to model.h5
# Epoch 85/100
# 79/79 - 67s - loss: 0.2677 - val_loss: 0.4872
#
# Epoch 00085: val_loss improved from 0.49502 to 0.48720, saving model to model.h5
# Epoch 86/100
# 79/79 - 68s - loss: 0.2614 - val_loss: 0.4836
#
# Epoch 00086: val_loss improved from 0.48720 to 0.48358, saving model to model.h5
# Epoch 87/100
# 79/79 - 67s - loss: 0.2510 - val_loss: 0.4775
#
# Epoch 00087: val_loss improved from 0.48358 to 0.47754, saving model to model.h5
# Epoch 88/100
# 79/79 - 68s - loss: 0.2445 - val_loss: 0.4722
#
# Epoch 00088: val_loss improved from 0.47754 to 0.47217, saving model to model.h5
# Epoch 89/100
# 79/79 - 67s - loss: 0.2377 - val_loss: 0.4680
#
# Epoch 00089: val_loss improved from 0.47217 to 0.46804, saving model to model.h5
# Epoch 90/100
# 79/79 - 67s - loss: 0.2272 - val_loss: 0.4628
#
# Epoch 00090: val_loss improved from 0.46804 to 0.46284, saving model to model.h5
# Epoch 91/100
# 79/79 - 67s - loss: 0.2226 - val_loss: 0.4565
#
# Epoch 00091: val_loss improved from 0.46284 to 0.45647, saving model to model.h5
# Epoch 92/100
# 79/79 - 67s - loss: 0.2165 - val_loss: 0.4630
#
# Epoch 00092: val_loss did not improve from 0.45647
# Epoch 93/100
# 79/79 - 68s - loss: 0.2187 - val_loss: 0.4660
#
# Epoch 00093: val_loss did not improve from 0.45647
# Epoch 94/100
# 79/79 - 67s - loss: 0.2126 - val_loss: 0.4468
#
# Epoch 00094: val_loss improved from 0.45647 to 0.44683, saving model to model.h5
# Epoch 95/100
# 79/79 - 67s - loss: 0.1983 - val_loss: 0.4376
#
# Epoch 00095: val_loss improved from 0.44683 to 0.43757, saving model to model.h5
# Epoch 96/100
# 79/79 - 67s - loss: 0.1852 - val_loss: 0.4340
#
# Epoch 00096: val_loss improved from 0.43757 to 0.43399, saving model to model.h5
# Epoch 97/100
# 79/79 - 68s - loss: 0.1770 - val_loss: 0.4311
#
# Epoch 00097: val_loss improved from 0.43399 to 0.43105, saving model to model.h5
# Epoch 98/100
# 79/79 - 68s - loss: 0.1715 - val_loss: 0.4223
#
# Epoch 00098: val_loss improved from 0.43105 to 0.42235, saving model to model.h5
# Epoch 99/100
# 79/79 - 68s - loss: 0.1640 - val_loss: 0.4192
#
# Epoch 00099: val_loss improved from 0.42235 to 0.41922, saving model to model.h5
# Epoch 100/100
# 79/79 - 68s - loss: 0.1569 - val_loss: 0.4149
#
# Epoch 00100: val_loss improved from 0.41922 to 0.41486, saving model to model.h5

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-Norwegian-both.pkl')
train = load_clean_sentences('english-Norwegian-train.pkl')
test = load_clean_sentences('english-Norwegian-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[Jeg håper dagens ballspill ikke blir avlyst], target=[I hope todays ball game wont be canceled], predicted=[i hope todays ball game wont be canceled]
# src=[Pengene mine ble stjålet], target=[I had my money stolen], predicted=[i had my money stolen]
# src=[Jeg ble forbløffet over resultatene], target=[I was amazed at the results], predicted=[i was amazed at the results]
# src=[Hun skrudde ned radioen], target=[She turned down the radio], predicted=[she turned down the radio]
# src=[Jeg hater å bo alene], target=[I hate living alone], predicted=[i hate living alone]
# src=[Dere venter her], target=[You guys wait here], predicted=[you guys wait here]
# src=[De tok passene våre], target=[They took our passports], predicted=[they took our passports]
# src=[La oss prøve noe], target=[Lets try something], predicted=[lets try something]
# src=[Hønene våre la mange egg i går], target=[Our hens laid a lot of eggs yesterday], predicted=[the hens laid a lot of eggs yesterday]
# src=[Du har funnet en god mann], target=[Youve found a good man], predicted=[youve found a good man]
# BLEU-1: 0.703987
# BLEU-2: 0.623880
# BLEU-3: 0.578073
# BLEU-4: 0.461988
# test
# src=[Tom har gått ned 30 pund], target=[Tom has lost 30 pounds], predicted=[tom has lost 30 pounds]
# src=[Det var nesten ingen barn i rommet], target=[Few children were in the room], predicted=[there were were in the room]
# src=[De glemmer igjen og igjen å betale regningene], target=[They keep forgetting to pay the bills], predicted=[they keep forgetting to pay the bills]
# src=[Tom fikk en parkeringsbot i går ettermiddag], target=[Tom got a parking ticket yesterday afternoon], predicted=[tom had a parking ticket yesterday afternoon]
# src=[Hei du ikke løp], target=[Hey you don’t run], predicted=[hey you don’t run]
# src=[Jeg er oppvokst på landet], target=[I grew up in the country], predicted=[i grew up in the country]
# src=[Gutten kom løpende], target=[The boy came running], predicted=[the boy came running]
# src=[Du vil fortsatt at jeg kommer gjør du ikke], target=[You still want me to come dont you], predicted=[you still want to what they dont you]
# src=[Jeg syntes prøven var vanskelig], target=[I found the test difficult], predicted=[i found the test difficult]
# src=[Du kan studere her], target=[You can study here], predicted=[you can study here]
# BLEU-1: 0.609337
# BLEU-2: 0.526840
# BLEU-3: 0.490580
# BLEU-4: 0.383382
